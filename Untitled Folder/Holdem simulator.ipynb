# %%
import random
from collections import defaultdict

# %%
class poker_player:
    def __init__(self, index):
        self.cards = []
        self.index = index
        self.value = None
    
    def draw(self, card):
        if len(self.cards) <= 2:
            self.cards.append(card)
            return True
        print(f"player{self.index} has enough cards")
        return False
    
    def discard(self):
        self.cards = []
        self.value = None
    
    def __repr__(self):
        if not self.cards:
            return f"player{self.index} does not have any card"
        cards = " ".join([str(card) for card in self.cards])
        return f"player{self.index} has {len(self.cards)} cards \n{cards}"

# %%
class poker_card:
    def __init__(self, suit, value):
        self.suit = suit
        self.value = value
        if value == 1:
            self.number = "A"
        elif value < 11:
            self.number = str(self.value)
        elif value == 11:
            self.number = "J"
        elif value == 12:
            self.number = "Q"
        elif value == 13:
            self.number = "K"
        else:
            raise Exception("WRONG VALUE")
        
    def __repr__(self):
        return f"{self.suit}{self.number}"

# %%
class holdem:
    suits = [u"\u2660", u"\u2661", u"\u2662",u"\u2663"]
    number_range = 13
    card_values = {
        1: "Royal flush",
        2: "Straight flush",
        3: "Four of a kind",
        4: "Full house",
        5: "Flush",
        6: "Straight",
        7: "Three of a kind",
        8: "Two pairs",
        9: "Pair",
        10: "Highcard"
    }
    def __init__(self, players=5):
        self.players = players
        self.begin_game()
        
    def add_player(self):
        self.player_list.append(poker_player(len(self.player_list)+1))
    
    def begin_game(self):
        self.player_list = []
        self.table = []
        for i in range(self.players):
            self.player_list.append(poker_player(i+1))
        self.init_cards()

    def init_cards(self):
        self.cards = []
        for suit in self.suits:
            for number in range(self.number_range):
                self.cards.append(poker_card(suit, number+1))
                
    def restore_players(self):
        self.table = []
        for player in self.player_list:
            player.discard()
        self.init_cards()
                
    def deal(self):
        random.shuffle(self.cards)
        for _ in range(2):
            for player in self.player_list:
                card = self.cards.pop()
                status = player.draw(card)
                if not status:
                    cards.append(card)
                    continue
        for _ in range(5):
            self.table.append(self.cards.pop())
#         print("Cards on the table are: ")
#         for card in self.table:
#             print(card,end=" ")
#         print()
#         for player in self.player_list:
#             print(player)
#             self.Royal_Flush(player, cards_dict)

    def check_values(self, player):
        cards_pool = player.cards + self.table
        cards_dict = defaultdict(set)
        
#         cards = " ".join([str(card) for card in sorted(cards_pool,key=lambda x:x.value)])
#         print( f"player{player.index}: \n{cards}")
        for card in cards_pool:
            cards_dict[card.value].add(card.suit)
        self.Highcard(player, cards_dict)
        self.Pair(player, cards_dict)
        self.Two_Pairs(player, cards_dict)
        self.Three_of_a_Kind(player, cards_dict)
        self.Straight(player, cards_dict)
        self.Flush(player, cards_dict)
        self.Full_House(player, cards_dict)
        self.Four_of_a_Kind(player, cards_dict)
        self.Straight_Flush(player, cards_dict)
        self.Royal_Flush(player, cards_dict)
        
    def check_winner(self):
        value_list = []
        count = 0
        for player in self.player_list:
            count += 1
            self.check_values(player)
            value_list.append([player.value, count, player])
        value_list.sort()
        winner_value = value_list[0][0]
#         winner = []
#         while value_list and value_list[0][0] == winner_value:
#             winner.append(value_list.pop(0)[2])
#         winner_name = ", ".join([str(player.index) for player in winner])
#         print(f"winner: \n{winner_name}\ncard is {self.card_values[winner_value]}")
        return winner_value

    def Royal_Flush(self, player, cards_dict):
        suits10 = cards_dict.get(10)
        if not suits10:
            return
        suitsJ = cards_dict.get(11)
        if not suitsJ:
            return
        suitsQ = cards_dict.get(12)
        if not suitsQ:
            return
        suitsK = cards_dict.get(13)
        if not suitsK:
            return
        suitsA = cards_dict.get(1)
        if not suitsA:
            return
        flag = False
        for suit in suits10:
            if suit not in suitsJ:
                continue
            if suit not in suitsQ:
                continue
            if suit not in suitsK:
                continue
            if suit not in suitsA:
                continue
            flag = True
        
        if flag:
            player.value = 1
            
    def Straight_Flush(self, player, cards_dict):
        flag = False
        for start in range(1,10):
            suits10 = cards_dict.get(start)
            if not suits10:
                continue
            suitsJ = cards_dict.get(start+1)
            if not suitsJ:
                continue
            suitsQ = cards_dict.get(start+2)
            if not suitsQ:
                continue
            suitsK = cards_dict.get(start+3)
            if not suitsK:
                continue
            suitsA = cards_dict.get(start+4)
            if not suitsA:
                continue
            flag = False
            for suit in suits10:
                if suit not in suitsJ:
                    continue
                if suit not in suitsQ:
                    continue
                if suit not in suitsK:
                    continue
                if suit not in suitsA:
                    continue
                flag = True
        if flag:
            player.value = 2
            
    def Four_of_a_Kind(self, player, cards_dict):
        for card in cards_dict:
            if len(cards_dict[card]) == 4:
                player.value = 3
                
    def Full_House(self, player, cards_dict):
        Three = False
        Two = False
        for card in cards_dict:
            if len(cards_dict[card]) == 3:
                if Three:
                    Two = True
                else:
                    Three = True
            elif len(cards_dict[card]) == 2:
                Two = True
        if Three and Two:
            player.value = 4
            
    def Flush(self, player, cards_dict):
        suits_dict = defaultdict(int)
        for card in cards_dict:
            for suit in cards_dict[card]:
                suits_dict[suit] += 1
                if suits_dict[suit] >= 5:
                    player.value = 5
    
    def top_straight(self, cards_dict):
        suits10 = cards_dict.get(10)
        if not suits10:
            return False
        suitsJ = cards_dict.get(11)
        if not suitsJ:
            return False
        suitsQ = cards_dict.get(12)
        if not suitsQ:
            return False
        suitsK = cards_dict.get(13)
        if not suitsK:
            return False
        suitsA = cards_dict.get(1)
        if not suitsA:
            return False
        return True
                    
    def Straight(self, player, cards_dict):
        if self.top_straight(cards_dict):
            player.value = 6
            return
        for start in range(1,10):
            suits10 = cards_dict.get(start)
            if not suits10:
                continue
            suitsJ = cards_dict.get(start+1)
            if not suitsJ:
                continue
            suitsQ = cards_dict.get(start+2)
            if not suitsQ:
                continue
            suitsK = cards_dict.get(start+3)
            if not suitsK:
                continue
            suitsA = cards_dict.get(start+4)
            if not suitsA:
                continue
            player.value = 6
            
    def Three_of_a_Kind(self, player, cards_dict):
        for card in cards_dict:
            if len(cards_dict[card]) == 3:
                player.value = 7
            
    def Two_Pairs(self, player, cards_dict):
        Two = False
        for card in cards_dict:
            if len(cards_dict[card]) == 2:
                if Two:
                    player.value = 8
                else:
                    Two = True
                
    def Pair(self, player, cards_dict):
        for card in cards_dict:
            if len(cards_dict[card]) == 2:
                player.value = 9
        
    def Highcard(self, player, cards_dict):
        player.value = 10

# %%
play = holdem()
count = 0
win_types = defaultdict(int)
while True:
    count += 1
    play.deal()
    winner_value = play.check_winner()
    win_types[winner_value] += 1
    play.restore_players()
    if win_types.get(1) == 10:
        print(f"In turn{count}")
        for t in win_types:
            print(f"{play.card_values[t]} has {win_types[t]/count}% probability")
        break
    if count % 1000 == 0:
        print(f"In turn{count}")
        for t in win_types:
            print(f"{play.card_values[t]} has {win_types[t]/count}% probability")
# Out:
# In turn1000
# Three of a kind has 0.125% probability
# Two pairs has 0.332% probability
# Pair has 0.203% probability
# Straight has 0.146% probability
# Full house has 0.09% probability
# Flush has 0.094% probability
# Royal flush has 0.001% probability
# Four of a kind has 0.006% probability
# Highcard has 0.002% probability
# Straight flush has 0.001% probability
# In turn2000
# Three of a kind has 0.12% probability
# Two pairs has 0.328% probability
# Pair has 0.203% probability
# Straight has 0.159% probability
# Full house has 0.0935% probability
# Flush has 0.0865% probability
# Royal flush has 0.0005% probability
# Four of a kind has 0.0065% probability
# Highcard has 0.0015% probability
# Straight flush has 0.0015% probability
# In turn3000
# Three of a kind has 0.12533333333333332% probability
# Two pairs has 0.32366666666666666% probability
# Pair has 0.19533333333333333% probability
# Straight has 0.15166666666666667% probability
# Full house has 0.10166666666666667% probability
# Flush has 0.09266666666666666% probability
# Royal flush has 0.0003333333333333333% probability
# Four of a kind has 0.006666666666666667% probability
# Highcard has 0.0016666666666666668% probability
# Straight flush has 0.001% probability
# In turn4000
# Three of a kind has 0.122% probability
# Two pairs has 0.3355% probability
# Pair has 0.19% probability
# Straight has 0.14875% probability
# Full house has 0.10225% probability
# Flush has 0.09225% probability
# Royal flush has 0.00025% probability
# Four of a kind has 0.00675% probability
# Highcard has 0.0015% probability
# Straight flush has 0.00075% probability
# In turn5000
# Three of a kind has 0.1244% probability
# Two pairs has 0.3352% probability
# Pair has 0.1876% probability
# Straight has 0.1468% probability
# Full house has 0.1024% probability
# Flush has 0.0946% probability
# Royal flush has 0.0002% probability
# Four of a kind has 0.0058% probability
# Highcard has 0.002% probability
# Straight flush has 0.001% probability
# In turn6000
# Three of a kind has 0.12683333333333333% probability
# Two pairs has 0.328% probability
# Pair has 0.18783333333333332% probability
# Straight has 0.148% probability
# Full house has 0.10133333333333333% probability
# Flush has 0.099% probability
# Royal flush has 0.00016666666666666666% probability
# Four of a kind has 0.006% probability
# Highcard has 0.002% probability
# Straight flush has 0.0008333333333333334% probability
# In turn7000
# Three of a kind has 0.127% probability
# Two pairs has 0.32542857142857146% probability
# Pair has 0.19171428571428573% probability
# Straight has 0.1467142857142857% probability
# Full house has 0.10042857142857142% probability
# Flush has 0.1% probability
# Royal flush has 0.00014285714285714287% probability
# Four of a kind has 0.006% probability
# Highcard has 0.0018571428571428571% probability
# Straight flush has 0.0007142857142857143% probability
# In turn8000
# Three of a kind has 0.128375% probability
# Two pairs has 0.32425% probability
# Pair has 0.19475% probability
# Straight has 0.145% probability
# Full house has 0.100125% probability
# Flush has 0.099375% probability
# Royal flush has 0.000125% probability
# Four of a kind has 0.00575% probability
# Highcard has 0.001625% probability
# Straight flush has 0.000625% probability
# In turn9000
# Three of a kind has 0.13% probability
# Two pairs has 0.32522222222222225% probability
# Pair has 0.19166666666666668% probability
# Straight has 0.14666666666666667% probability
# Full house has 0.09855555555555555% probability
# Flush has 0.099% probability
# Royal flush has 0.00011111111111111112% probability
# Four of a kind has 0.006% probability
# Highcard has 0.002% probability
# Straight flush has 0.0007777777777777777% probability
# In turn10000
# Three of a kind has 0.1276% probability
# Two pairs has 0.3247% probability
# Pair has 0.194% probability
# Straight has 0.1472% probability
# Full house has 0.0996% probability
# Flush has 0.098% probability
# Royal flush has 0.0001% probability
# Four of a kind has 0.0059% probability
# Highcard has 0.002% probability
# Straight flush has 0.0009% probability
# In turn11000
# Three of a kind has 0.12672727272727272% probability
# Two pairs has 0.327% probability
# Pair has 0.19463636363636364% probability
# Straight has 0.14672727272727273% probability
# Full house has 0.098% probability
# Flush has 0.0979090909090909% probability
# Royal flush has 9.09090909090909e-05% probability
# Four of a kind has 0.006090909090909091% probability
# Highcard has 0.0018181818181818182% probability
# Straight flush has 0.001% probability
# In turn12000
# Three of a kind has 0.12625% probability
# Two pairs has 0.32625% probability
# Pair has 0.19441666666666665% probability
# Straight has 0.14783333333333334% probability
# Full house has 0.09741666666666667% probability
# Flush has 0.09858333333333333% probability
# Royal flush has 8.333333333333333e-05% probability
# Four of a kind has 0.006416666666666667% probability
# Highcard has 0.0016666666666666668% probability
# Straight flush has 0.0010833333333333333% probability
# In turn13000
# Three of a kind has 0.12646153846153846% probability
# Two pairs has 0.3269230769230769% probability
# Pair has 0.1946923076923077% probability
# Straight has 0.14715384615384616% probability
# Full house has 0.09746153846153846% probability
# Flush has 0.09807692307692308% probability
# Royal flush has 7.692307692307693e-05% probability
# Four of a kind has 0.0063076923076923076% probability
# Highcard has 0.0016923076923076924% probability
# Straight flush has 0.001153846153846154% probability
# In turn14000
# Three of a kind has 0.12557142857142858% probability
# Two pairs has 0.32821428571428574% probability
# Pair has 0.1947142857142857% probability
# Straight has 0.1462142857142857% probability
# Full house has 0.09728571428571428% probability
# Flush has 0.09871428571428571% probability
# Royal flush has 7.142857142857143e-05% probability
# Four of a kind has 0.006285714285714286% probability
# Highcard has 0.0017142857142857142% probability
# Straight flush has 0.0012142857142857142% probability
# In turn15000
# Three of a kind has 0.12613333333333332% probability
# Two pairs has 0.3267333333333333% probability
# Pair has 0.19386666666666666% probability
# Straight has 0.146% probability
# Full house has 0.0976% probability
# Flush has 0.10006666666666666% probability
# Royal flush has 6.666666666666667e-05% probability
# Four of a kind has 0.0066% probability
# Highcard has 0.0016% probability
# Straight flush has 0.0013333333333333333% probability
# In turn16000
# Three of a kind has 0.1245625% probability
# Two pairs has 0.32625% probability
# Pair has 0.1955% probability
# Straight has 0.1468125% probability
# Full house has 0.097375% probability
# Flush has 0.09975% probability
# Royal flush has 6.25e-05% probability
# Four of a kind has 0.00675% probability
# Highcard has 0.001625% probability
# Straight flush has 0.0013125% probability
# In turn17000
# Three of a kind has 0.12417647058823529% probability
# Two pairs has 0.3251176470588235% probability
# Pair has 0.19694117647058823% probability
# Straight has 0.14570588235294119% probability
# Full house has 0.098% probability
# Flush has 0.10029411764705883% probability
# Royal flush has 0.00011764705882352942% probability
# Four of a kind has 0.006764705882352941% probability
# Highcard has 0.001588235294117647% probability
# Straight flush has 0.0012941176470588236% probability
# In turn18000
# Three of a kind has 0.12433333333333334% probability
# Two pairs has 0.32611111111111113% probability
# Pair has 0.19816666666666666% probability
# Straight has 0.1448888888888889% probability
# Full house has 0.0971111111111111% probability
# Flush has 0.09966666666666667% probability
# Royal flush has 0.00011111111111111112% probability
# Four of a kind has 0.006833333333333334% probability
# Highcard has 0.0015555555555555555% probability
# Straight flush has 0.0012222222222222222% probability
# In turn19000
# Three of a kind has 0.12363157894736843% probability
# Two pairs has 0.32710526315789473% probability
# Pair has 0.19789473684210526% probability
# Straight has 0.14542105263157895% probability
# Full house has 0.0958421052631579% probability
# Flush has 0.10036842105263158% probability
# Royal flush has 0.00010526315789473685% probability
# Four of a kind has 0.006842105263157895% probability
# Highcard has 0.0015789473684210526% probability
# Straight flush has 0.0012105263157894737% probability
# In turn20000
# Three of a kind has 0.12375% probability
# Two pairs has 0.3276% probability
# Pair has 0.19735% probability
# Straight has 0.1452% probability
# Full house has 0.0957% probability
# Flush has 0.10035% probability
# Royal flush has 0.0001% probability
# Four of a kind has 0.00715% probability
# Highcard has 0.00155% probability
# Straight flush has 0.00125% probability
# In turn21000
# Three of a kind has 0.12404761904761905% probability
# Two pairs has 0.32761904761904764% probability
# Pair has 0.19647619047619047% probability
# Straight has 0.14557142857142857% probability
# Full house has 0.09604761904761905% probability
# Flush has 0.10047619047619048% probability
# Royal flush has 9.523809523809524e-05% probability
# Four of a kind has 0.006952380952380952% probability
# Highcard has 0.0014761904761904762% probability
# Straight flush has 0.001238095238095238% probability
# In turn22000
# Three of a kind has 0.12386363636363637% probability
# Two pairs has 0.32745454545454544% probability
# Pair has 0.19736363636363635% probability
# Straight has 0.1455909090909091% probability
# Full house has 0.09586363636363636% probability
# Flush has 0.10009090909090909% probability
# Royal flush has 9.09090909090909e-05% probability
# Four of a kind has 0.006909090909090909% probability
# Highcard has 0.0014545454545454545% probability
# Straight flush has 0.0013181818181818182% probability
# In turn23000
# Three of a kind has 0.12395652173913044% probability
# Two pairs has 0.3267391304347826% probability
# Pair has 0.19717391304347825% probability
# Straight has 0.1456086956521739% probability
# Full house has 0.09630434782608696% probability
# Flush has 0.10052173913043479% probability
# Royal flush has 8.695652173913044e-05% probability
# Four of a kind has 0.006826086956521739% probability
# Highcard has 0.0014782608695652175% probability
# Straight flush has 0.0013043478260869566% probability
# In turn24000
# Three of a kind has 0.12383333333333334% probability
# Two pairs has 0.32616666666666666% probability
# Pair has 0.19691666666666666% probability
# Straight has 0.14558333333333334% probability
# Full house has 0.09654166666666666% probability
# Flush has 0.10108333333333333% probability
# Royal flush has 8.333333333333333e-05% probability
# Four of a kind has 0.007083333333333333% probability
# Highcard has 0.0014583333333333334% probability
# Straight flush has 0.00125% probability
# In turn25000
# Three of a kind has 0.1238% probability
# Two pairs has 0.32636% probability
# Pair has 0.19712% probability
# Straight has 0.14544% probability
# Full house has 0.09616% probability
# Flush has 0.10132% probability
# Royal flush has 8e-05% probability
# Four of a kind has 0.007% probability
# Highcard has 0.00144% probability
# Straight flush has 0.00128% probability
# In turn26000
# Three of a kind has 0.12473076923076923% probability
# Two pairs has 0.3262307692307692% probability
# Pair has 0.1968076923076923% probability
# Straight has 0.14526923076923076% probability
# Full house has 0.09626923076923077% probability
# Flush has 0.10096153846153846% probability
# Royal flush has 7.692307692307693e-05% probability
# Four of a kind has 0.007% probability
# Highcard has 0.0013846153846153845% probability
# Straight flush has 0.0012692307692307692% probability
# In turn27000
# Three of a kind has 0.12459259259259259% probability
# Two pairs has 0.32625925925925925% probability
# Pair has 0.19722222222222222% probability
# Straight has 0.1457037037037037% probability
# Full house has 0.0961111111111111% probability
# Flush has 0.10055555555555555% probability
# Royal flush has 0.00011111111111111112% probability
# Four of a kind has 0.006888888888888889% probability
# Highcard has 0.0013333333333333333% probability
# Straight flush has 0.0012222222222222222% probability
# In turn28000
# Three of a kind has 0.1245% probability
# Two pairs has 0.3261071428571429% probability
# Pair has 0.1972142857142857% probability
# Straight has 0.14592857142857144% probability
# Full house has 0.09614285714285714% probability
# Flush has 0.1005% probability
# Royal flush has 0.00010714285714285714% probability
# Four of a kind has 0.0069642857142857145% probability
# Highcard has 0.0013214285714285715% probability
# Straight flush has 0.0012142857142857142% probability
# In turn29000
# Three of a kind has 0.12458620689655173% probability
# Two pairs has 0.3263793103448276% probability
# Pair has 0.1966206896551724% probability
# Straight has 0.14593103448275863% probability
# Full house has 0.09637931034482759% probability
# Flush has 0.10058620689655172% probability
# Royal flush has 0.00010344827586206896% probability
# Four of a kind has 0.006896551724137931% probability
# Highcard has 0.001310344827586207% probability
# Straight flush has 0.001206896551724138% probability
# In turn30000
# Three of a kind has 0.1247% probability
# Two pairs has 0.32626666666666665% probability
# Pair has 0.19713333333333333% probability
# Straight has 0.14593333333333333% probability
# Full house has 0.0963% probability
# Flush has 0.1001% probability
# Royal flush has 0.0001% probability
# Four of a kind has 0.007% probability
# Highcard has 0.0013% probability
# Straight flush has 0.0011666666666666668% probability
# In turn31000
# Three of a kind has 0.12441935483870968% probability
# Two pairs has 0.32683870967741935% probability
# Pair has 0.19748387096774195% probability
# Straight has 0.14580645161290323% probability
# Full house has 0.09616129032258064% probability
# Flush has 0.09970967741935484% probability
# Royal flush has 9.67741935483871e-05% probability
# Four of a kind has 0.006967741935483871% probability
# Highcard has 0.0013548387096774194% probability
# Straight flush has 0.001161290322580645% probability
# In turn32000
# Three of a kind has 0.12453125% probability
# Two pairs has 0.32684375% probability
# Pair has 0.19696875% probability
# Straight has 0.14584375% probability
# Full house has 0.09640625% probability
# Flush has 0.099625% probability
# Royal flush has 0.000125% probability
# Four of a kind has 0.00715625% probability
# Highcard has 0.001375% probability
# Straight flush has 0.001125% probability
# In turn33000
# Three of a kind has 0.12448484848484849% probability
# Two pairs has 0.32684848484848483% probability
# Pair has 0.19690909090909092% probability
# Straight has 0.14536363636363636% probability
# Full house has 0.09627272727272727% probability
# Flush has 0.10033333333333333% probability
# Royal flush has 0.00012121212121212121% probability
# Four of a kind has 0.007151515151515152% probability
# Highcard has 0.001393939393939394% probability
# Straight flush has 0.0011212121212121212% probability
# In turn34000
# Three of a kind has 0.12411764705882353% probability
# Two pairs has 0.3266176470588235% probability
# Pair has 0.19726470588235295% probability
# Straight has 0.14605882352941177% probability
# Full house has 0.0961764705882353% probability
# Flush has 0.09991176470588235% probability
# Royal flush has 0.00011764705882352942% probability
# Four of a kind has 0.00711764705882353% probability
# Highcard has 0.0014705882352941176% probability
# Straight flush has 0.0011470588235294118% probability
# In turn35000
# Three of a kind has 0.12488571428571428% probability
# Two pairs has 0.3261142857142857% probability
# Pair has 0.19688571428571428% probability
# Straight has 0.1462857142857143% probability
# Full house has 0.0962% probability
# Flush has 0.09968571428571428% probability
# Royal flush has 0.00011428571428571428% probability
# Four of a kind has 0.007257142857142857% probability
# Highcard has 0.0014285714285714286% probability
# Straight flush has 0.001142857142857143% probability
# In turn36000
# Three of a kind has 0.12477777777777778% probability
# Two pairs has 0.32630555555555557% probability
# Pair has 0.1971388888888889% probability
# Straight has 0.14552777777777778% probability
# Full house has 0.09644444444444444% probability
# Flush has 0.09986111111111111% probability
# Royal flush has 0.0001388888888888889% probability
# Four of a kind has 0.00725% probability
# Highcard has 0.001388888888888889% probability
# Straight flush has 0.0011666666666666668% probability
# In turn37000
# Three of a kind has 0.12535135135135136% probability
# Two pairs has 0.32591891891891894% probability
# Pair has 0.19702702702702704% probability
# Straight has 0.14581081081081082% probability
# Full house has 0.09645945945945945% probability
# Flush has 0.09943243243243244% probability
# Royal flush has 0.00013513513513513514% probability
# Four of a kind has 0.0073513513513513516% probability
# Highcard has 0.0013513513513513514% probability
# Straight flush has 0.0011621621621621622% probability
# In turn38000
# Three of a kind has 0.12536842105263157% probability
# Two pairs has 0.32573684210526316% probability
# Pair has 0.19739473684210526% probability
# Straight has 0.14568421052631578% probability
# Full house has 0.09652631578947368% probability
# Flush has 0.0993421052631579% probability
# Royal flush has 0.00013157894736842105% probability
# Four of a kind has 0.007368421052631579% probability
# Highcard has 0.0013157894736842105% probability
# Straight flush has 0.001131578947368421% probability
# In turn39000
# Three of a kind has 0.12528205128205128% probability
# Two pairs has 0.32605128205128203% probability
# Pair has 0.19715384615384615% probability
# Straight has 0.14566666666666667% probability
# Full house has 0.09682051282051282% probability
# Flush has 0.09912820512820512% probability
# Royal flush has 0.0001282051282051282% probability
# Four of a kind has 0.007333333333333333% probability
# Highcard has 0.0013333333333333333% probability
# Straight flush has 0.0011025641025641025% probability
# In turn40000
# Three of a kind has 0.125475% probability
# Two pairs has 0.325975% probability
# Pair has 0.197275% probability
# Straight has 0.145525% probability
# Full house has 0.0967% probability
# Flush has 0.0992% probability
# Royal flush has 0.000125% probability
# Four of a kind has 0.007275% probability
# Highcard has 0.001375% probability
# Straight flush has 0.001075% probability
# In turn41000
# Three of a kind has 0.1254390243902439% probability
# Two pairs has 0.3264390243902439% probability
# Pair has 0.1969268292682927% probability
# Straight has 0.1456341463414634% probability
# Full house has 0.09636585365853659% probability
# Flush has 0.09919512195121952% probability
# Royal flush has 0.00014634146341463414% probability
# Four of a kind has 0.007317073170731708% probability
# Highcard has 0.0014390243902439024% probability
# Straight flush has 0.0010975609756097562% probability
# In turn42000
# Three of a kind has 0.12533333333333332% probability
# Two pairs has 0.3262380952380952% probability
# Pair has 0.19697619047619047% probability
# Straight has 0.14576190476190476% probability
# Full house has 0.0965% probability
# Flush has 0.09928571428571428% probability
# Royal flush has 0.00014285714285714287% probability
# Four of a kind has 0.007238095238095238% probability
# Highcard has 0.0014285714285714286% probability
# Straight flush has 0.0010952380952380953% probability
# In turn43000
# Three of a kind has 0.12551162790697673% probability
# Two pairs has 0.32588372093023255% probability
# Pair has 0.19697674418604652% probability
# Straight has 0.1459767441860465% probability
# Full house has 0.09681395348837209% probability
# Flush has 0.09895348837209303% probability
# Royal flush has 0.00013953488372093022% probability
# Four of a kind has 0.007209302325581395% probability
# Highcard has 0.0014651162790697675% probability
# Straight flush has 0.0010697674418604652% probability
# In turn44000
# Three of a kind has 0.12554545454545454% probability
# Two pairs has 0.3255681818181818% probability
# Pair has 0.1968409090909091% probability
# Straight has 0.14638636363636365% probability
# Full house has 0.09677272727272727% probability
# Flush has 0.0989090909090909% probability
# Royal flush has 0.00013636363636363637% probability
# Four of a kind has 0.00725% probability
# Highcard has 0.0015454545454545454% probability
# Straight flush has 0.0010454545454545454% probability
# In turn45000
# Three of a kind has 0.12588888888888888% probability
# Two pairs has 0.3253333333333333% probability
# Pair has 0.19704444444444444% probability
# Straight has 0.14642222222222223% probability
# Full house has 0.09664444444444445% probability
# Flush has 0.09877777777777778% probability
# Royal flush has 0.00013333333333333334% probability
# Four of a kind has 0.007177777777777778% probability
# Highcard has 0.0015333333333333334% probability
# Straight flush has 0.0010444444444444444% probability
# In turn46000
# Three of a kind has 0.1257608695652174% probability
# Two pairs has 0.3259565217391304% probability
# Pair has 0.19652173913043477% probability
# Straight has 0.14621739130434783% probability
# Full house has 0.09691304347826087% probability
# Flush has 0.09863043478260869% probability
# Royal flush has 0.00013043478260869564% probability
# Four of a kind has 0.007217391304347826% probability
# Highcard has 0.0015869565217391305% probability
# Straight flush has 0.001065217391304348% probability
# In turn47000
# Three of a kind has 0.12580851063829787% probability
# Two pairs has 0.32593617021276594% probability
# Pair has 0.19674468085106384% probability
# Straight has 0.1462340425531915% probability
# Full house has 0.09695744680851064% probability
# Flush has 0.09827659574468085% probability
# Royal flush has 0.0001276595744680851% probability
# Four of a kind has 0.007276595744680851% probability
# Highcard has 0.0015957446808510637% probability
# Straight flush has 0.0010425531914893618% probability
# In turn48000
# Three of a kind has 0.12614583333333335% probability
# Two pairs has 0.32575% probability
# Pair has 0.19697916666666668% probability
# Straight has 0.14585416666666667% probability
# Full house has 0.0969375% probability
# Flush has 0.09835416666666667% probability
# Royal flush has 0.000125% probability
# Four of a kind has 0.007208333333333333% probability
# Highcard has 0.001625% probability
# Straight flush has 0.0010208333333333332% probability
# In turn49000
# Three of a kind has 0.12608163265306122% probability
# Two pairs has 0.32571428571428573% probability
# Pair has 0.19691836734693877% probability
# Straight has 0.14606122448979592% probability
# Full house has 0.09689795918367347% probability
# Flush has 0.09842857142857143% probability
# Royal flush has 0.00012244897959183673% probability
# Four of a kind has 0.00710204081632653% probability
# Highcard has 0.0016530612244897958% probability
# Straight flush has 0.0010204081632653062% probability
# In turn50000
# Three of a kind has 0.12652% probability
# Two pairs has 0.32522% probability
# Pair has 0.1969% probability
# Straight has 0.14624% probability
# Full house has 0.09678% probability
# Flush has 0.09842% probability
# Royal flush has 0.00014% probability
# Four of a kind has 0.0071% probability
# Highcard has 0.00166% probability
# Straight flush has 0.00102% probability
# In turn51000
# Three of a kind has 0.12631372549019607% probability
# Two pairs has 0.3251176470588235% probability
# Pair has 0.19698039215686275% probability
# Straight has 0.14633333333333334% probability
# Full house has 0.09666666666666666% probability
# Flush has 0.09854901960784314% probability
# Royal flush has 0.0001372549019607843% probability
# Four of a kind has 0.007215686274509804% probability
# Highcard has 0.0016862745098039215% probability
# Straight flush has 0.001% probability
# In turn52000
# Three of a kind has 0.1265769230769231% probability
# Two pairs has 0.3246730769230769% probability
# Pair has 0.19725% probability
# Straight has 0.14621153846153845% probability
# Full house has 0.09667307692307692% probability
# Flush has 0.09863461538461539% probability
# Royal flush has 0.0001346153846153846% probability
# Four of a kind has 0.007153846153846154% probability
# Highcard has 0.0017115384615384616% probability
# Straight flush has 0.0009807692307692308% probability
# In turn53000
# Three of a kind has 0.1261320754716981% probability
# Two pairs has 0.32432075471698113% probability
# Pair has 0.19758490566037737% probability
# Straight has 0.14673584905660378% probability
# Full house has 0.09639622641509434% probability
# Flush has 0.09877358490566038% probability
# Royal flush has 0.0001320754716981132% probability
# Four of a kind has 0.007207547169811321% probability
# Highcard has 0.0017547169811320755% probability
# Straight flush has 0.0009622641509433962% probability
# In turn54000
# Three of a kind has 0.1260925925925926% probability
# Two pairs has 0.3242777777777778% probability
# Pair has 0.19748148148148148% probability
# Straight has 0.14672222222222223% probability
# Full house has 0.09640740740740741% probability
# Flush has 0.0989074074074074% probability
# Royal flush has 0.00012962962962962963% probability
# Four of a kind has 0.007240740740740741% probability
# Highcard has 0.0017777777777777779% probability
# Straight flush has 0.000962962962962963% probability
# In turn55000
# Three of a kind has 0.12587272727272728% probability
# Two pairs has 0.3240909090909091% probability
# Pair has 0.19761818181818183% probability
# Straight has 0.14714545454545455% probability
# Full house has 0.09645454545454546% probability
# Flush has 0.09878181818181818% probability
# Royal flush has 0.00012727272727272728% probability
# Four of a kind has 0.0072% probability
# Highcard has 0.0017454545454545455% probability
# Straight flush has 0.0009636363636363637% probability
# In turn56000
# Three of a kind has 0.12607142857142858% probability
# Two pairs has 0.3239642857142857% probability
# Pair has 0.19748214285714286% probability
# Straight has 0.14760714285714285% probability
# Full house has 0.09614285714285714% probability
# Flush has 0.09864285714285714% probability
# Royal flush has 0.000125% probability
# Four of a kind has 0.007214285714285714% probability
# Highcard has 0.0017678571428571428% probability
# Straight flush has 0.0009821428571428572% probability
# In turn57000
# Three of a kind has 0.1260175438596491% probability
# Two pairs has 0.32426315789473686% probability
# Pair has 0.19756140350877194% probability
# Straight has 0.14759649122807017% probability
# Full house has 0.09601754385964913% probability
# Flush has 0.09843859649122808% probability
# Royal flush has 0.00012280701754385965% probability
# Four of a kind has 0.007192982456140351% probability
# Highcard has 0.0017894736842105263% probability
# Straight flush has 0.001% probability
# In turn58000
# Three of a kind has 0.1261551724137931% probability
# Two pairs has 0.3243793103448276% probability
# Pair has 0.1969655172413793% probability
# Straight has 0.1478103448275862% probability
# Full house has 0.09586206896551724% probability
# Flush has 0.09865517241379311% probability
# Royal flush has 0.0001206896551724138% probability
# Four of a kind has 0.007224137931034482% probability
# Highcard has 0.001810344827586207% probability
# Straight flush has 0.0010172413793103447% probability
# In turn59000
# Three of a kind has 0.12635593220338984% probability
# Two pairs has 0.32440677966101694% probability
# Pair has 0.19694915254237289% probability
# Straight has 0.1474406779661017% probability
# Full house has 0.09623728813559322% probability
# Flush has 0.09849152542372881% probability
# Royal flush has 0.00011864406779661017% probability
# Four of a kind has 0.007186440677966101% probability
# Highcard has 0.0018135593220338982% probability
# Straight flush has 0.001% probability
# In turn60000
# Three of a kind has 0.12623333333333334% probability
# Two pairs has 0.3239666666666667% probability
# Pair has 0.19743333333333332% probability
# Straight has 0.1477% probability
# Full house has 0.09626666666666667% probability
# Flush has 0.09828333333333333% probability
# Royal flush has 0.00011666666666666667% probability
# Four of a kind has 0.007183333333333333% probability
# Highcard has 0.0018166666666666667% probability
# Straight flush has 0.001% probability
# In turn61000
# Three of a kind has 0.12655737704918033% probability
# Two pairs has 0.3230983606557377% probability
# Pair has 0.19768852459016392% probability
# Straight has 0.1474590163934426% probability
# Full house has 0.09654098360655737% probability
# Flush has 0.09849180327868852% probability
# Royal flush has 0.00011475409836065574% probability
# Four of a kind has 0.00719672131147541% probability
# Highcard has 0.0018524590163934427% probability
# Straight flush has 0.001% probability
# In turn62000
# Three of a kind has 0.1267258064516129% probability
# Two pairs has 0.323241935483871% probability
# Pair has 0.19741935483870968% probability
# Straight has 0.1475% probability
# Full house has 0.09653225806451612% probability
# Flush has 0.09841935483870967% probability
# Royal flush has 0.00012903225806451613% probability
# Four of a kind has 0.007161290322580645% probability
# Highcard has 0.0018709677419354838% probability
# Straight flush has 0.001% probability
# In turn63000
# Three of a kind has 0.1268253968253968% probability
# Two pairs has 0.32306349206349205% probability
# Pair has 0.19766666666666666% probability
# Straight has 0.1472857142857143% probability
# Full house has 0.09671428571428571% probability
# Flush has 0.0983015873015873% probability
# Royal flush has 0.00012698412698412698% probability
# Four of a kind has 0.007095238095238095% probability
# Highcard has 0.001888888888888889% probability
# Straight flush has 0.0010317460317460319% probability
# In turn64000
# Three of a kind has 0.12684375% probability
# Two pairs has 0.323171875% probability
# Pair has 0.19784375% probability
# Straight has 0.147171875% probability
# Full house has 0.096578125% probability
# Flush has 0.098203125% probability
# Royal flush has 0.000125% probability
# Four of a kind has 0.007171875% probability
# Highcard has 0.001859375% probability
# Straight flush has 0.00103125% probability
# In turn65000
# Three of a kind has 0.12678461538461538% probability
# Two pairs has 0.32372307692307695% probability
# Pair has 0.1975230769230769% probability
# Straight has 0.14724615384615386% probability
# Full house has 0.09653846153846155% probability
# Flush has 0.09804615384615385% probability
# Royal flush has 0.00012307692307692307% probability
# Four of a kind has 0.007169230769230769% probability
# Highcard has 0.0018307692307692309% probability
# Straight flush has 0.0010153846153846155% probability
# In turn66000
# Three of a kind has 0.12653030303030302% probability
# Two pairs has 0.32375757575757574% probability
# Pair has 0.19757575757575757% probability
# Straight has 0.1471060606060606% probability
# Full house has 0.09666666666666666% probability
# Flush has 0.09824242424242424% probability
# Royal flush has 0.00012121212121212121% probability
# Four of a kind has 0.007136363636363636% probability
# Highcard has 0.0018333333333333333% probability
# Straight flush has 0.0010303030303030303% probability
# In turn67000
# Three of a kind has 0.1265373134328358% probability
# Two pairs has 0.32344776119402985% probability
# Pair has 0.19770149253731342% probability
# Straight has 0.14720895522388058% probability
# Full house has 0.09667164179104477% probability
# Flush has 0.09829850746268656% probability
# Royal flush has 0.00013432835820895522% probability
# Four of a kind has 0.007119402985074627% probability
# Highcard has 0.001835820895522388% probability
# Straight flush has 0.001044776119402985% probability
# In turn68000
# Three of a kind has 0.1264705882352941% probability
# Two pairs has 0.3235294117647059% probability
# Pair has 0.1978235294117647% probability
# Straight has 0.1473970588235294% probability
# Full house has 0.09644117647058824% probability
# Flush has 0.0981764705882353% probability
# Royal flush has 0.00013235294117647058% probability
# Four of a kind has 0.00711764705882353% probability
# Highcard has 0.0018529411764705882% probability
# Straight flush has 0.0010588235294117646% probability
# In turn69000
# Three of a kind has 0.126231884057971% probability
# Two pairs has 0.3240144927536232% probability
# Pair has 0.1976376811594203% probability
# Straight has 0.14742028985507247% probability
# Full house has 0.09627536231884058% probability
# Flush has 0.09826086956521739% probability
# Royal flush has 0.00013043478260869564% probability
# Four of a kind has 0.00708695652173913% probability
# Highcard has 0.0018695652173913043% probability
# Straight flush has 0.001072463768115942% probability
# In turn70000
# Three of a kind has 0.1264% probability
# Two pairs has 0.3241857142857143% probability
# Pair has 0.19752857142857144% probability
# Straight has 0.14732857142857142% probability
# Full house has 0.09628571428571428% probability
# Flush has 0.09807142857142857% probability
# Royal flush has 0.00012857142857142858% probability
# Four of a kind has 0.0071142857142857145% probability
# Highcard has 0.0019% probability
# Straight flush has 0.0010571428571428572% probability
# In turn70188
# Three of a kind has 0.12633213654755798% probability
# Two pairs has 0.3241722231720522% probability
# Pair has 0.19758363252977718% probability
# Straight has 0.14734712486464924% probability
# Full house has 0.09629851256625065% probability
# Flush has 0.09807944377956346% probability
# Royal flush has 0.00014247449706502536% probability
# Four of a kind has 0.007095229953838263% probability
# Highcard has 0.0018949108109648373% probability
# Straight flush has 0.0010543112782811876% probability

# %%
a = [1,2,3]
a.pop()
print(U"\u2661")
# Out:
# ♡

# %%
a = set([1,2,3])
len(a)
# Out:
# 3
